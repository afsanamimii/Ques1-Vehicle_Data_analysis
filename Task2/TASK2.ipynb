# %%
import pandas as pd
import numpy as np
import json

# %% [markdown]
# # Loading the data

# %%
data = pd.read_csv("E:\MINERVA PROJECT 1\Copy of stop_times.txt",delimiter=",")

# %%
data
# Out:
#                     trip_id arrival_time departure_time stop_id  \
# 0        112387248235954071     21:07:00       21:07:00    4014
# 1        112387248235954071     21:09:00       21:09:00    3231
# 2        112387248235954071     21:10:08       21:10:08    3232
# 3        112387248235954071     21:11:00       21:11:00    3233
# 4        112387248235954071     21:11:43       21:11:43    3239
# ...                     ...          ...            ...     ...
# 2820504  113028649236519600     07:29:00       07:29:00   6427F
# 2820505  113028649236519600     07:30:00       07:30:00   6430F
# 2820506  113028649236519600     07:31:35       07:31:35   5066F
# 2820507  113028649236519600     07:33:00       07:33:00   5068F
# 2820508  113028649236519600     07:34:00       07:34:00    6361
#
#          stop_sequence  pickup_type  drop_off_type
# 0                    1            0              0
# 1                    2            0              0
# ...

# %% [markdown]
# # Find out the array index's list for slicing the data

# %%
stop_ids = (data[(data["stop_sequence"] == 1)]).index.tolist()

# %%
stop_ids
# Out:
# [0,
#  31,
#  62,
#  93,
#  124,
#  155,
#  186,
#  203,
#  234,
#  265,
#  296,
#  327,
#  358,
#  389,
#  420,
#  451,
#  482,
#  513,
#  544,
#  575,
#  606,
#  637,
#  668,
#  699,
#  730,
#  761,
#  792,
#  823,
#  854,
#  885,
#  916,
#  947,
#  978,
#  1009,
#  1040,
#  1071,
#  1102,
#  1133,
#  1164,
#  1195,
#  1226,
#  1257,
#  1288,
#  1319,
#  1350,
#  1381,
#  1412,
#  1443,
#  1474,
#  1505,
#  1536,
#  1567,
#  1598,
#  1629,
#  1660,
#  1691,
#  1722,
#  1753,
#  1784,
#  1815,
#  1846,
#  1877,
#  1908,
#  1939,
#  1970,
#  2001,
#  2032,
#  2063,
#  2094,
#  2111,
#  2142,
#  2173,
#  2204,
#  2235,
#  2266,
#  2297,
#  2328,
#  2359,
#  2390,
#  2421,
#  2452,
#  2483,
#  2514,
#  2545,
#  2576,
#  2607,
#  2638,
#  2669,
#  2700,
#  2731,
#  2762,
#  2793,
#  2824,
#  2855,
#  2886,
#  2917,
#  2948,
#  2979,
#  3010,
#  3041,
#  3072,
#  3103,
#  3134,
#  3165,
#  3196,
#  3227,
#  3258,
#  3289,
#  3320,
#  3351,
#  3382,
#  3413,
#  3444,
#  3475,
#  3506,
# ...

# %%
len(stop_ids)
# Out:
# 135249

# %% [markdown]
# # Assign a column for vehicle id where all value is 0

# %%
data['vehicle_id']=0

# %%
data
# Out:
#                     trip_id arrival_time departure_time stop_id  \
# 0        112387248235954071     21:07:00       21:07:00    4014
# 1        112387248235954071     21:09:00       21:09:00    3231
# 2        112387248235954071     21:10:08       21:10:08    3232
# 3        112387248235954071     21:11:00       21:11:00    3233
# 4        112387248235954071     21:11:43       21:11:43    3239
# ...                     ...          ...            ...     ...
# 2820504  113028649236519600     07:29:00       07:29:00   6427F
# 2820505  113028649236519600     07:30:00       07:30:00   6430F
# 2820506  113028649236519600     07:31:35       07:31:35   5066F
# 2820507  113028649236519600     07:33:00       07:33:00   5068F
# 2820508  113028649236519600     07:34:00       07:34:00    6361
#
#          stop_sequence  pickup_type  drop_off_type  vehicle_id
# 0                    1            0              0           0
# 1                    2            0              0           0
# ...

# %% [markdown]
# # Logical part

# %% [markdown]
# For each unique slice I will add a random value

# %%
import random

# %%
for i in range(len(stop_ids)):
    if(i+1<len(stop_ids)):
        print(stop_ids[i],":",stop_ids[i+1])
        #final=data[stop_ids[i]:stop_ids[i+1]].copy()
        data.loc[data.index[stop_ids[i]:stop_ids[i+1]], 'vehicle_id'] =random.randint(0,4000000)
# Out:
# 0 : 31
